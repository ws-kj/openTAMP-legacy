# %%
import numpy as np

# %%
path = "/Users/phillipchristoffersen/PycharmProjects/openTAMP/opentamp/experiment_logs/namo_objs1_1/test_namo_performance_long_0/test_namo_performance_long_0/moretest_hl_test_log.npy"
arr = np.load(path)
print(arr.shape)
# Out:
# (28135, 1, 20)

# %%
plan_suc_rate = arr[:,:,12]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(plan_suc_rate),), plan_suc_rate)
